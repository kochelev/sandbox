# %%
import requests

msg = "msg1"

response = requests.post(
    url=f"http://localhost:8000/api/{msg}",
    params={
        "my_query": "aaa"
    },
    headers={
        "my-header": "bbb"
    }
)

response.status_code
# Out:
# 200

# %%
response.text
# Out:
# '{"detail":"Method Not Allowed"}'

# %%
response.json()
# Out:
# 'ok'
