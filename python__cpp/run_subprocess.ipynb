# %%
import subprocess

# %%
subprocess.run(['ls'])
# Out:
# hello_world.cpp
# hello_world.so
# hello_world_cpp
# requirements.txt
# run_ctypes.ipynb
# run_subprocess.ipynb
# venv
# vs.code-workspace
# CompletedProcess(args=['ls'], returncode=0)

# %% [markdown]
# # Компилляция и запуск приложения на С++
#
# ## Шаг 1: проверить версию компиллятора

# %%
# !g++ -v
# Out:
# Apple clang version 14.0.3 (clang-1403.0.22.14.1)
# Target: arm64-apple-darwin22.5.0
# Thread model: posix
# InstalledDir: /Applications/Xcode.app/Contents/Developer/Toolchains/XcodeDefault.xctoolchain/usr/bin

# %% [markdown]
# ## Шаг 2: скомпиллировать файл **hello_world.cpp**

# %%
# !g++ -o ./hello_world_cpp ./hello_world.cpp

# %% [markdown]
# ## Шаг 3: запустить приложение через терминал

# %%
# !./hello_world_cpp
# Out:
# Hello World! I'm C++

# %% [markdown]
# ## Шаг 4: запустить приложение с помощью Python

# %%
subprocess.run(['./hello_world_cpp'])
# Out:
# Hello World! I'm C++
# CompletedProcess(args=['./hello_world_cpp_2'], returncode=0)
