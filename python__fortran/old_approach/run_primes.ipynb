# %% [markdown]
# ```shell
# f2py -c -m primes primes.f95 --fcompiler=gfortran
# ```

# %%
import primes
import numpy as np

help(primes)
# Out:
# Help on module primes:
#
# NAME
#     primes
#
# DESCRIPTION
#     This module 'primes' is auto-generated with f2py (version:2.3.4).
#     Functions:
#         is_prime = sieve(n_max)
#         prime_numbers = logical_to_integer(is_prime,num_primes,n=shape(is_prime, 0))
#     .
#
# DATA
#     __f2py_numpy_version__ = '2.3.4'
#     logical_to_integer = <fortran function logical_to_integer>
#     sieve = <fortran function sieve>
#
# VERSION
#     2.3.4
#
# FILE
#     /Users/maestro/Desktop/Лаборатория/Примеры кода/python__fortran/primes.cpython-313-darwin.so

# %%
print(primes.sieve.__doc__)
# Out:
# is_prime = sieve(n_max)
#
# Wrapper for ``sieve``.
#
# Parameters
# ----------
# n_max : input int
#
# Returns
# -------
# is_prime : rank-1 array('i') with bounds (n_max)

# %%
print(primes.logical_to_integer.__doc__)
# Out:
# prime_numbers = logical_to_integer(is_prime,num_primes,[n])
#
# Wrapper for ``logical_to_integer``.
#
# Parameters
# ----------
# is_prime : input rank-1 array('i') with bounds (n)
# num_primes : input int
#
# Other Parameters
# ----------------
# n : input int, optional
#     Default: shape(is_prime, 0)
#
# Returns
# -------
# prime_numbers : rank-1 array('i') with bounds (num_primes)

# %%
from time import time

start_time = time()

result = primes.sieve(1_000_000_000)

finish_time = time()

print(finish_time - start_time)
# Out:
# 13.303888320922852
